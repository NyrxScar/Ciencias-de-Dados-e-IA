# %%
linguagens_populares = {'Python': 2, 'Java': 1, 'Javascript': 3}
chaves = linguagens_populares.keys()
print(f"Estas são as chaves - {list(chaves)}")
# Out:
# Estas são as chaves - ['Python', 'Java', 'Javascript']

# %%
pets = [ "Anúbis", "Wanreda", "Mitsuki", "Layo", "Iráma"]
print(pets)
servicos = { "Limpeza bocal": 20, "Banho": 95, "Tosa": 110, "Raio x": 300, "Vacina": 120}
preço = servicos.keys()
tutor = [ "Tutor A", "Tutor B", "Tutor C", "Tutor D", "Tutor E"]
data = ["21/04/25", "22/04/25",  "23/04/25",  "24/04/25", "25/04/25"]
# for i in range(len(pets)):
#     agenda = dict(zip(pets,[{"tutor": tutor, "servicos": servicos, "data" : data}]))
# print(agenda)

agenda = dict(zip(pets,[{"tutor": tutor[i], "servicos": preço, "data": data[i]} for i in range(len(pets))]))
print(agenda)
#    - valor: outro dicionário com as chaves "tutor", "servico", "preco" e "data".
# Out:
# ['Anúbis', 'Wanreda', 'Mitsuki', 'Layo', 'Iráma']
# {'Anúbis': {'tutor': 'Tutor A', 'servicos': dict_keys(['Limpeza bocal', 'Banho', 'Tosa', 'Raio x', 'Vacina']), 'data': '21/04/25'}, 'Wanreda': {'tutor': 'Tutor B', 'servicos': dict_keys(['Limpeza bocal', 'Banho', 'Tosa', 'Raio x', 'Vacina']), 'data': '22/04/25'}, 'Mitsuki': {'tutor': 'Tutor C', 'servicos': dict_keys(['Limpeza bocal', 'Banho', 'Tosa', 'Raio x', 'Vacina']), 'data': '23/04/25'}, 'Layo': {'tutor': 'Tutor D', 'servicos': dict_keys(['Limpeza bocal', 'Banho', 'Tosa', 'Raio x', 'Vacina']), 'data': '24/04/25'}, 'Iráma': {'tutor': 'Tutor E', 'servicos': dict_keys(['Limpeza bocal', 'Banho', 'Tosa', 'Raio x', 'Vacina']), 'data': '25/04/25'}}
