# %% [markdown]
# Avaliação de Algoritmos e Programação

# %% [markdown]
# O que Fazer:
#
# AV2 - Sistema de Cadastro de Itens para Lista de Compras com MENU
# Objetivo Geral
# Construir um programa em Python que utilize boas práticas de programação
# (comentários, estrutura limpa), implementando as funcionalidades descritas abaixo:
# • Uso de laço while
# • Condicionais if/else (sem elif)
# • Listas
# • Variáveis de controle e contadores
# • MENU de opções
#
# O que se espera do programa
# 1. Exibir um MENU principal com opções:
# • Adicionar item - Confere
# • Exibir lista  - Confere
# • Sair - Confere
# 2. Cadastro de itens para uma lista de compras enquanto o usuário desejar, limitado a
# 10 itens válidos.
# 3. Uso de lista para armazenar os itens válidos. -
# 4. Interrupção voluntária através do menu (opção Sair).
# 5. Verificação de item vazio: itens vazios não devem ser aceitos.
# 6. Impedir itens duplicados: não permitir cadastro de itens repetidos.
# 7. Solicitação de confirmação antes de cadastrar: confirmar com (sim/não) antes de
# adicionar à lista.
# 8. Exibir relatório final ao escolher “Sair”: lista de itens cadastrados, total de itens
# adicionados e total de rejeições (itens vazios, duplicados ou cancelados).
#
# Dicas de boas práticas
# • Utilize comentários explicando cada parte do código.
# • Nomeie variáveis de forma clara e coerente.
# • Organize o código em ENTRADA, PROCESSAMENTO e SAÍDA.
# • Estruture o menu com a palavra MENU claramente visível na interface do
# programa.
#
# Exemplo de interação com o usuário
# ==== MENU ====
# 1. Adicionar item
# 2. Exibir lista de itens
# 3. Sair
# Escolha uma opção: 1
# Nome do item: arroz
# Você confirma o cadastro de 'arroz'? (sim/não): sim
# Item registrado com sucesso.
# ==== MENU ====
# 1. Adicionar item
# 2. Exibir lista de itens
# 3. Sair
# Escolha uma opção: 1
# Nome do item: arroz
# Item já cadastrado. Evite duplicidades.
# ==== MENU ====
# 1. Adicionar item
# 2. Exibir lista de itens
# 3. Sair
# Escolha uma opção: 2
# Lista atual de itens:
# • arroz
# ==== MENU ====
# 1. Adicionar item
# 2. Exibir lista de itens
# 3. Sair
# Escolha uma opção: 3
# Relatório Final:
# Itens cadastrados: ['arroz']
# Total de itens adicionados: 1
# Total de rejeições: 1
#
# Critérios de Avaliação
# A nota máxima da prova é 10 pontos, distribuída conforme a complexidade de cada item:
#
# Critério Avaliado Pontuação Observação / Complexidade
# MENU conforme enunciado 1,0 Estruturar menu e controlar fluxo
# Cadastro com limite de 10 itens 0,5 Controle simples
# Uso de lista 0,5 Estrutura básica
# Saída pelo menu 0,5 Controle simples
# Não aceita vazio 1,0 Validação básica
# Impede duplicados 1,5 Requer checagem/controle extra
# Confirmação sim/não antes de cadastrar 1,5 Requer fluxo alternativo
# Relatório final completo 1,5 Integração de contadores e lista
# Organização e comentários 1,0 Clareza, didática, estrutura
# Uso apenas de if/else 1,0 Atenção à lógica
# TOTAL 10
# Observações
# • O código deve estar comentado e organizado em Entrada, Processamento e
# Saída.
# • O uso de elif não será aceito; utilize apenas if e else.
# • É obrigatória a exibição da palavra MENU na interface do programa.
# • O relatório final deve conter:
# o Lista dos itens cadastrados
# o Total de itens adicionados
# o Total de rejeições (itens vazios, duplicados ou cancelados)

# %% [markdown]
# Código da Prova

# %%
lista_de_compras = []  # Aqui a gente cria a lista onde os itens vão ser guardados
rejeicoes_do_menu = 0  # Contador que vai marcar quantas vezes o usuário tentou algo inválido (tipo item repetido, vazio, ou recusou confirmar)

print("AV2 - Sistema de Cadastro de Itens para Lista de Compras com MENU")


# Esse while True cria um laço infinito, que só vai parar quando o usuário escolher sair (opção 3)
while True:
    # Mostra o menu principal pro usuário com as 3 opções básicas
    print("\n MENU de Opções: 1 - Adicionar item; 2 - Exibir lista de itens; 3 - Sair")

    menu_de_escolha = input("Escolha uma opção: ")
    
    # Se o usuário escolher 1, ele vai adicionar um novo item à lista
    if menu_de_escolha == "1":
        # Primeiro, verifica se já tem 10 itens. Se sim, avisa que não dá pra adicionar mais
        if len(lista_de_compras) >= 10:
            print("\nLimite máximo de 10 itens atingido!")
        else:
            # Pede o nome do item ao usuário e remove espaços em branco nas pontas (tipo "   arroz   " vira "arroz")
            item_da_lista = input("Nome do item: ").strip()
            
            if item_da_lista == "":
                # Se o usuário não digitar nada (ou só espaços), avisa que não pode e aumenta o contador de rejeições
                print("Item vazio não é aceito!")
                rejeicoes_do_menu += 1
            else:
                # Verifica se o item já está na lista. Se sim, não deixa repetir e conta como rejeição
                if item_da_lista in lista_de_compras:
                    print("Item já cadastrado. Evite duplicidades.")
                    rejeicoes_do_menu += 1
                else:
                    # Se passou nas validações, pergunta pro usuário se ele confirma a adição do item
                    confirmacao = input(f"Você confirma o cadastro de '{item_da_lista}'? (sim/não): ").lower()
                    if confirmacao == "sim":
                        # Se o usuário confirmar, o item é adicionado na lista
                        lista_de_compras.append(item_da_lista)
                        print("Item registrado com sucesso.")
                    else:
                        # Se ele desistir, o cadastro é cancelado e conta como rejeição também
                        print("Cadastro cancelado.")
                        rejeicoes_do_menu += 1
    
    else:
        # Se o usuário escolheu a opção 2, o programa exibe os itens da lista
        if menu_de_escolha == "2":
            if not lista_de_compras:
                # Se a lista estiver vazia, avisa pro usuário que não tem nada ainda
                print("\nLista vazia. Adicione itens primeiro.")
            else:
                # Se tiver itens, mostra todos eles em formato de lista
                print("\nLista atual de itens:")
                for item_da_lista in lista_de_compras:
                    print(f"• {item_da_lista}")
        else:
            # Se for a opção 3, o programa exibe um relatório final e sai do loop (termina)
            if menu_de_escolha == "3":
                print("\nRelatório Final:")
                print("Itens cadastrados:")
                for item_da_lista in lista_de_compras:
                    print(f" • {item_da_lista};")
                print(f"Total de itens adicionados: {len(lista_de_compras)}")
                print(f"Total de rejeições: {rejeicoes_do_menu}")
                print("O Programa da 'AV2 - Sistema de Cadastro de Itens para Lista de Compras com MENU' foi finalizado.")
                break  # Aqui é onde o loop infinito é quebrado, ou seja, o programa termina
            
            else:
                # Se o usuário digitar algo que não é 1, 2 ou 3, dá esse aviso
                print("Opção inválida ou Erro. Escolha 1, 2 ou 3 das opções do Menu faladas anteriormente.")

# %% [markdown]
# Códigos para Consulta e Pesquisa a partir de Atividades Feitas Anteriormente: Pode ignorar, são para fins de pesquisa

# %% [markdown]
# #####################
#
# # Fazendo sem o try e except
#
# carrosDisponiveis = ["Gol", "Fusca", "Palio", "Uno", "Vectra"]
#
# carrosReservados = []
#
# while len(carrosReservados) < 5:
#     for index, word in enumerate(carrosDisponiveis):
#         print(f"Carros disponíveis: {index} - {word}")
#     print("\n" )
#     IndiceCarroReservar = input("Digite o número(indice) do carro que você deseja reservar ou 'sair' para encerrar o programa: ")
#     if IndiceCarroReservar == "sair":
#         print("Programa encerrado")
#         break
#
#     else:
#             if IndiceCarroReservar.isdigit():
#                 reservarCarro = int(IndiceCarroReservar)
#                 if reservarCarro in range(len(carrosDisponiveis)) :
#                     carro = carrosDisponiveis[reservarCarro]
#                     carrosReservados.append(carro)
#                     carrosDisponiveis.remove(carro)
#                     print(f"\nCarro reservado com sucesso: {carro}")
#                     print(f"Carros disponíveis ainda: {carrosDisponiveis}\n")
#                     print(f"Você reservou os seguintes carros: {carrosReservados}\n")
#                     print(f"Rodando o programa novamente, você pode reservar mais {5 - len(carrosReservados)} carro(s)...\n")
#
#                 else:
#                     print("\nCarro não disponível\n")
#             else:
#                 print("\nEntrada inválida. Digite um número ou 'sair'.\n")
#
# if len(carrosReservados) == 5:
#     print("\nSem estoque, todos os carros foram reservados e obrigada pela preferência\n")
#
# ########################################################
#
# # Com o try e except
#
# carrosDisponiveis = ["Gol", "Fusca", "Palio", "Uno", "Vectra"]
# carrosReservados = []
#
# while len(carrosReservados) < 5:
#     for index, word in enumerate(carrosDisponiveis):
#         print(f"Carros disponíveis: {index} - {word}")
#     print("\n")
#
#     IndiceCarroReservar = input("Digite o número(indice) do carro que você deseja reservar ou 'sair' para encerrar o programa: ")
#
#     if IndiceCarroReservar.lower() == "sair":
#         print("Programa encerrado")
#         break
#
#     try:
#         reservarCarro = int(IndiceCarroReservar)
#
#         if reservarCarro in range(len(carrosDisponiveis)):
#             carro = carrosDisponiveis[reservarCarro]
#             carrosReservados.append(carro)
#             carrosDisponiveis.remove(carro)
#             print(f"\nCarro reservado com sucesso: {carro}")
#             print(f"Carros disponíveis ainda: {carrosDisponiveis}\n")
#             print(f"Você reservou os seguintes carros: {carrosReservados}\n")
#             print(f"Rodando o programa novamente, você pode reservar mais {5 - len(carrosReservados)} carro(s)...\n")
#         else:
#             print("\nCarro não disponível\n")
#     except ValueError:
#         print("\nEntrada inválida. Digite um número válido ou 'sair'.\n")
#
# if len(carrosReservados) == 5:
#     print("\nSem estoque, todos os carros foram reservados e obrigada pela preferência!\n")

# %% [markdown]
#  dica:  for i,fruta in enumerate (frutas, start=1): #enumera cada item da lista 'frutas', começando por 1
#             print(f"{i}. {fruta}")

# %% [markdown]
# print("Digite '1' para sexo biológicamente 'Masculino' e '2' para 'Feminino")
# escolha_sexo = str(input("Digite o número correspondente ao seu sexo biológico: "))
# risco1 = ""
#
#
# if escolha_sexo == "1":
#     print("Seu sexo biológico é Masculino")
# else:
#     if escolha_sexo == "2":
#         print("Seu sexo biológico é Feminino")
#     else:
#         print("Desculpe, não temos dados para pessoas intersexo ou outras opções")
#
# print("Meça a circuferência do seu abdômen! ")
#
# circuferencia_abdomen = float(input("Digite sua circufência em centimetros: "))
#
# if (circuferencia_abdomen >= 94) and (circuferencia_abdomen < 102) and ("1"):
#     risco1 = "Aumentado"
# else:
#     if (circuferencia_abdomen >= 102) and ("1"):
#          risco1 = "Substancialmente Aumentado"
#     else:
#         if (circuferencia_abdomen >= 80) and (circuferencia_abdomen < 88) and ("2"):
#             risco1 = "Aumentado"
#         else:
#             if (circuferencia_abdomen >= 88) and ("2"):
#                 risco1 = "Substancialmente Aumentado"
#             else:
#                 if (circuferencia_abdomen < 94):
#                     risco1 = "atualmente nulo"
#
# print(f"Seu IMC de acordo com o seu sexo tem potencial {risco1} de comorbidade")

# %%
# 1 - Busca simples com for [Melhorado]

# encontrarNome = False
# Listanomes = []

# for i in range(5):
#     print("Digite 15 nomes para adicionar à lista do alunos")
#     AdicionarListanomes = str(input("Digite o nome que vc quer adicionar à lista: "))
#     Listanomes.append(AdicionarListanomes)
#     print(Listanomes)

# procurado = str(input("Digite o nome que vc quer encontrar na lista: "))
# for elementos in Listanomes:
#     if elementos == procurado:
#         print(f"O nome '{procurado}' está na lista na posição {Listanomes.index(procurado)+1}")
#         break
#     if encontrarNome:
#         print(f"O nome '{procurado}' não está na lista")
    
# print(f"Fim do programa")
